# %%
import os
import sys

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    if not os.path.exists("forde-vision-language"):
        # !git clone https://github.com/dylanbforde/forde-vision-language.git
        # %cd forde-vision-language
    else:
        # %cd forde-vision-language
        # !git pull

    # !pip install -e .
    # !pip install tensorboard ipykernel

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python src/training/train.py \
    --num_epochs 1 \
    --max_steps 100 \
    --batch_size 4 \
    --log_interval 10
