# %%
import os
import sys

try:
    from google.colab import drive
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    if not os.path.exists("forde-vision-language"):
        # !git clone https://github.com/dylanbforde/forde-vision-language.git
        # %cd forde-vision-language
    else:
        # %cd forde-vision-language
        # !git pull

    # !pip install -e .
    # !pip install tensorboard ipykernel

# %%
# Note: If TensorBoard shows old runs, try the 'Reload' button in the TB interface
# or run this cell again. Each run now has a unique timestamp.
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# You can change --experiment_name to distinguish different runs
# !python src/training/train.py \
    --num_epochs 1 \
    --max_steps 100000 \
    --batch_size 6 \
    --log_interval 10 \
    --checkpoint_dir checkpoints \
    --experiment_name "colab_run"

# %%
if IN_COLAB:
    from google.colab import drive
    import datetime
    import shutil

    # Mount Google Drive
    drive.mount('/content/drive')

    # Create a timestamped zip file
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    backup_name = f"forde_llm_backup_{timestamp}"
    
    print(f"Zipping outputs to {backup_name}.zip...")
    # !zip -r {backup_name}.zip runs checkpoints

    # Copy to Drive
    dest_path = f"/content/drive/My Drive/{backup_name}.zip"
    print(f"Copying to {dest_path}...")
    shutil.copy(f"{backup_name}.zip", dest_path)
    print("Backup complete! Output saved to Google Drive.")
else:
    print("Not running in Colab. Checkpoints and logs are already saved locally in 'checkpoints/' and 'runs/'.")
